# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
gray_image = cv2.imread('ex2.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.title("Grayscale Image")
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(1307.5), np.float64(-0.5))

# %%
print("Name : Bhuvaneshwaran \n Register Number : 212223240018")

plt.title("Histogram of Grayscale Image")
plt.hist(gray_image.ravel(), bins=256, color='black', alpha=0.6)
plt.xlim(0, 255)
plt.tight_layout()
plt.show()
# Out:
# Name : Bhuvaneshwaran
#  Register Number : 212223240018

# %%
equalized_gray_image = cv2.equalizeHist(gray_image)

# %%
plt.title("Histogram of Equalized Grayscale Image")
plt.hist(equalized_gray_image.ravel(), bins=256, color='black', alpha=0.6)
plt.xlim(0, 255)
# Out:
# (0.0, 255.0)

# %%
plt.title("Enhanced Grayscale Image")
plt.imshow(equalized_gray_image, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(1307.5), np.float64(-0.5))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
color_image = cv2.imread('gt650.jpg')

# %%
plt.title("Input Color Image")
plt.imshow(cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(473.5), np.float64(824.5), np.float64(-0.5))

# %%
hist_b = cv2.calcHist([color_image], [0], None, [256], [0, 256])
hist_g = cv2.calcHist([color_image], [1], None, [256], [0, 256])
hist_r = cv2.calcHist([color_image], [2], None, [256], [0, 256])

# %%
print("Name : Bhuvaneshwaran H \n Register Number : 212223240018")


plt.title("Histogram of Input Color Image")
plt.plot(hist_b, color='blue', label='Blue channel')
plt.plot(hist_g, color='green', label='Green channel')
plt.plot(hist_r, color='red', label='Red channel')
plt.show()
# Out:
# Name : Bhuvaneshwaran H
#  Register Number : 212223240018
